# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

x_train = x_train.reshape((-1, 784))
x_test = x_test.reshape((-1, 784))

# %%
input_img = layers.Input(shape=(784,))
encoded = layers.Dense(64, activation='swish')(input_img)

decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = models.Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
es = EarlyStopping (monitor='loss', patience = 10, restore_best_weights=True)

history = autoencoder.fit(
    x_train, x_train,
    epochs=100,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test),
    callbacks = [es]
)
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0808 - val_loss: 0.0271
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0249 - val_loss: 0.0201
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0191 - val_loss: 0.0168
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0146 - val_loss: 0.0139
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0136 - val_loss: 0.0131
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0128 - val_loss: 0.0126
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0124 - val_loss: 0.0122
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0113 - val_loss: 0.0113
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0093 - val_loss: 0.0094
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0085 - val_loss: 0.0087

# %%
decoded_imgs = autoencoder.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
n = 3
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')
plt.show()

# %% [markdown]
# #  Minimal Dense Autoencoder for Fashion MNIST – Summary and Learnings
#
# ## Model Summary
#
# This implementation uses a **minimal fully-connected autoencoder** to compress and reconstruct grayscale images from the **Fashion MNIST** dataset. The model architecture consists of only two Dense layers: one for encoding (compression) and one for decoding (reconstruction).
#
# This setup serves as a simple baseline for evaluating autoencoder performance and learning representation quality using dense layers alone.
#
# ---
#
# ##  Model Architecture
#
# - **Input Shape**: `(784,)` (flattened 28×28 image)
# - **Encoder**:
#   - `Dense(64, activation='relu')` – learns a 64-dimensional compressed representation
# - **Decoder**:
#   - `Dense(784, activation='sigmoid')` – reconstructs the input from encoded features
#
# ---
#
# ##  Training and Optimization
#
# - **Dataset**: Fashion MNIST (grayscale 28×28 clothing images)
# - **Preprocessing**:
#   - Normalize pixel values to [0, 1]
#   - Flatten images to vectors of size 784
# - **Loss Function**: `Mean Squared Error (MSE)`
# - **Optimizer**: `Adam`
# - **Evaluation**:
#   - Training and validation loss plotted over epochs
#   - Visual comparison between original and reconstructed images
#
# ---
#
# ##  Learnings
#
# - A single dense encoding layer can learn basic structure and features from Fashion MNIST, but reconstructions are often blurry or lack fine detail.
# - Despite its simplicity, this model can serve as a strong baseline for more complex architectures like convolutional autoencoders.
# - ReLU activation in the encoder promotes sparse representations, while sigmoid in the output layer ensures pixel values remain between 0 and 1.
# - Adding more layers or switching to convolutional models significantly improves image quality and feature retention.
#
# ---
#
# ##  Limitations
#
# - Spatial features are not preserved due to flattening.
# - Struggles with more detailed or color images.
# - Poor performance on noisy or real-world image data without additional regularization or denoising mechanisms.
