# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3),
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.3),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.4),

    layers.Conv2D(128, (3, 3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu',
                  kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),

    layers.Flatten(),
    layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import math
def cosine_decay(epoch, total_epochs=200, initial_lr=0.01, min_lr=1e-6):
    cosine_decay_val = 0.5 * (1 + math.cos(math.pi * epoch / total_epochs))
    decayed_lr = (initial_lr - min_lr) * cosine_decay_val + min_lr
    return decayed_lr

initial_learning_rate = 0.001
lr_scheduler_callback = LearningRateScheduler(
    lambda epoch: cosine_decay(epoch, total_epochs=150, initial_lr=initial_learning_rate, min_lr=1e-7)
)

callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=25, restore_best_weights=True, verbose=1),
    lr_scheduler_callback
]

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
)


history = model.fit(datagen.flow(train_images, train_labels, batch_size=64),
                    epochs=100,
                    validation_data=(test_images, test_labels),
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 52ms/step - accuracy: 0.2862 - loss: 2.3345 - val_accuracy: 0.4193 - val_loss: 1.8247 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.4572 - loss: 1.6297 - val_accuracy: 0.4763 - val_loss: 1.7550 - learning_rate: 9.9989e-04
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.5409 - loss: 1.4325 - val_accuracy: 0.5873 - val_loss: 1.3620 - learning_rate: 9.9956e-04
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.5860 - loss: 1.3330 - val_accuracy: 0.6586 - val_loss: 1.1537 - learning_rate: 9.9901e-04
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6302 - loss: 1.2494 - val_accuracy: 0.6411 - val_loss: 1.2502 - learning_rate: 9.9825e-04
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.6573 - loss: 1.1748 - val_accuracy: 0.6577 - val_loss: 1.1950 - learning_rate: 9.9726e-04
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.6798 - loss: 1.1356 - val_accuracy: 0.6830 - val_loss: 1.1645 - learning_rate: 9.9606e-04
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - accuracy: 0.7000 - loss: 1.0905 - val_accuracy: 0.7218 - val_loss: 1.0261 - learning_rate: 9.9464e-04
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.7140 - loss: 1.0637 - val_accuracy: 0.7349 - val_loss: 1.0191 - learning_rate: 9.9300e-04
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - accuracy: 0.7211 - loss: 1.0464 - val_accuracy: 0.7402 - val_loss: 1.0080 - learning_rate: 9.9114e-04
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7313 - loss: 1.0176 - val_accuracy: 0.7365 - val_loss: 1.0288 - learning_rate: 9.8907e-04
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7376 - loss: 0.9976 - val_accuracy: 0.6527 - val_loss: 1.3429 - learning_rate: 9.8679e-04
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7472 - loss: 0.9880 - val_accuracy: 0.7459 - val_loss: 1.0087 - learning_rate: 9.8429e-04
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7518 - loss: 0.9780 - val_accuracy: 0.7623 - val_loss: 0.9670 - learning_rate: 9.8158e-04
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7581 - loss: 0.9620 - val_accuracy: 0.7895 - val_loss: 0.8762 - learning_rate: 9.7866e-04
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7587 - loss: 0.9594 - val_accuracy: 0.8119 - val_loss: 0.8104 - learning_rate: 9.7553e-04
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7677 - loss: 0.9402 - val_accuracy: 0.7505 - val_loss: 1.0063 - learning_rate: 9.7219e-04
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7682 - loss: 0.9358 - val_accuracy: 0.7473 - val_loss: 1.0161 - learning_rate: 9.6864e-04
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7742 - loss: 0.9315 - val_accuracy: 0.8119 - val_loss: 0.8321 - learning_rate: 9.6489e-04
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7724 - loss: 0.9313 - val_accuracy: 0.8063 - val_loss: 0.8431 - learning_rate: 9.6094e-04
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7788 - loss: 0.9179 - val_accuracy: 0.7657 - val_loss: 0.9706 - learning_rate: 9.5678e-04
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.7810 - loss: 0.9177 - val_accuracy: 0.7458 - val_loss: 1.0346 - learning_rate: 9.5242e-04
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7857 - loss: 0.9021 - val_accuracy: 0.8182 - val_loss: 0.8123 - learning_rate: 9.4786e-04
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - accuracy: 0.7863 - loss: 0.9057 - val_accuracy: 0.8058 - val_loss: 0.8404 - learning_rate: 9.4311e-04
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7867 - loss: 0.8951 - val_accuracy: 0.8117 - val_loss: 0.8275 - learning_rate: 9.3816e-04
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7915 - loss: 0.8858 - val_accuracy: 0.8012 - val_loss: 0.8534 - learning_rate: 9.3302e-04
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 40ms/step - accuracy: 0.7917 - loss: 0.8806 - val_accuracy: 0.8049 - val_loss: 0.8561 - learning_rate: 9.2769e-04
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7950 - loss: 0.8709 - val_accuracy: 0.8288 - val_loss: 0.7707 - learning_rate: 9.2217e-04
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7946 - loss: 0.8718 - val_accuracy: 0.8088 - val_loss: 0.8215 - learning_rate: 9.1647e-04
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7980 - loss: 0.8636 - val_accuracy: 0.8119 - val_loss: 0.8504 - learning_rate: 9.1058e-04
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 40ms/step - accuracy: 0.8021 - loss: 0.8496 - val_accuracy: 0.8115 - val_loss: 0.8426 - learning_rate: 9.0452e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7988 - loss: 0.8617 - val_accuracy: 0.7972 - val_loss: 0.8694 - learning_rate: 8.9828e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7998 - loss: 0.8567 - val_accuracy: 0.7905 - val_loss: 0.8869 - learning_rate: 8.9186e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7988 - loss: 0.8522 - val_accuracy: 0.8122 - val_loss: 0.8202 - learning_rate: 8.8527e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8027 - loss: 0.8488 - val_accuracy: 0.8000 - val_loss: 0.8712 - learning_rate: 8.7851e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8032 - loss: 0.8421 - val_accuracy: 0.8089 - val_loss: 0.8453 - learning_rate: 8.7159e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8070 - loss: 0.8391 - val_accuracy: 0.8247 - val_loss: 0.7943 - learning_rate: 8.6450e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8074 - loss: 0.8302 - val_accuracy: 0.8370 - val_loss: 0.7490 - learning_rate: 8.5725e-04
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8101 - loss: 0.8269 - val_accuracy: 0.7532 - val_loss: 1.0096 - learning_rate: 8.4985e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8112 - loss: 0.8221 - val_accuracy: 0.7978 - val_loss: 0.8944 - learning_rate: 8.4229e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8110 - loss: 0.8181 - val_accuracy: 0.8296 - val_loss: 0.7664 - learning_rate: 8.3458e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8134 - loss: 0.8141 - val_accuracy: 0.8348 - val_loss: 0.7538 - learning_rate: 8.2673e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8077 - loss: 0.8195 - val_accuracy: 0.8325 - val_loss: 0.7694 - learning_rate: 8.1873e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8151 - loss: 0.8089 - val_accuracy: 0.8473 - val_loss: 0.7043 - learning_rate: 8.1059e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8138 - loss: 0.8005 - val_accuracy: 0.8456 - val_loss: 0.7125 - learning_rate: 8.0232e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8106 - loss: 0.8033 - val_accuracy: 0.8433 - val_loss: 0.7399 - learning_rate: 7.9391e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8152 - loss: 0.7957 - val_accuracy: 0.8252 - val_loss: 0.7918 - learning_rate: 7.8538e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8187 - loss: 0.7890 - val_accuracy: 0.8332 - val_loss: 0.7529 - learning_rate: 7.7672e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8195 - loss: 0.7809 - val_accuracy: 0.8065 - val_loss: 0.8460 - learning_rate: 7.6794e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8209 - loss: 0.7804 - val_accuracy: 0.8366 - val_loss: 0.7433 - learning_rate: 7.5904e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8235 - loss: 0.7640 - val_accuracy: 0.8064 - val_loss: 0.8442 - learning_rate: 7.5002e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8218 - loss: 0.7732 - val_accuracy: 0.8225 - val_loss: 0.7844 - learning_rate: 7.4090e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8251 - loss: 0.7618 - val_accuracy: 0.8463 - val_loss: 0.7057 - learning_rate: 7.3167e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8225 - loss: 0.7644 - val_accuracy: 0.8131 - val_loss: 0.8249 - learning_rate: 7.2235e-04
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8248 - loss: 0.7637 - val_accuracy: 0.8186 - val_loss: 0.8052 - learning_rate: 7.1292e-04
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8261 - loss: 0.7583 - val_accuracy: 0.8474 - val_loss: 0.7066 - learning_rate: 7.0340e-04
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 39ms/step - accuracy: 0.8260 - loss: 0.7526 - val_accuracy: 0.8238 - val_loss: 0.7780 - learning_rate: 6.9379e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8262 - loss: 0.7473 - val_accuracy: 0.8120 - val_loss: 0.8131 - learning_rate: 6.8409e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8292 - loss: 0.7395 - val_accuracy: 0.8255 - val_loss: 0.7581 - learning_rate: 6.7432e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.8250 - loss: 0.7410 - val_accuracy: 0.8250 - val_loss: 0.7658 - learning_rate: 6.6447e-04
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8265 - loss: 0.7382 - val_accuracy: 0.8087 - val_loss: 0.8370 - learning_rate: 6.5454e-04
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8308 - loss: 0.7267 - val_accuracy: 0.8182 - val_loss: 0.7963 - learning_rate: 6.4455e-04
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8275 - loss: 0.7328 - val_accuracy: 0.8134 - val_loss: 0.7965 - learning_rate: 6.3450e-04
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8325 - loss: 0.7248 - val_accuracy: 0.8301 - val_loss: 0.7358 - learning_rate: 6.2438e-04
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8323 - loss: 0.7199 - val_accuracy: 0.8311 - val_loss: 0.7512 - learning_rate: 6.1421e-04
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8302 - loss: 0.7161 - val_accuracy: 0.8258 - val_loss: 0.7478 - learning_rate: 6.0400e-04
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8329 - loss: 0.7081 - val_accuracy: 0.8324 - val_loss: 0.7178 - learning_rate: 5.9373e-04
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8353 - loss: 0.7052 - val_accuracy: 0.8471 - val_loss: 0.6887 - learning_rate: 5.8343e-04
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8398 - loss: 0.6880 - val_accuracy: 0.8302 - val_loss: 0.7268 - learning_rate: 5.7308e-04
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8362 - loss: 0.6930 - val_accuracy: 0.8457 - val_loss: 0.6776 - learning_rate: 5.6271e-04
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8385 - loss: 0.6936 - val_accuracy: 0.8527 - val_loss: 0.6625 - learning_rate: 5.5231e-04
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.8387 - loss: 0.6881 - val_accuracy: 0.8565 - val_loss: 0.6442 - learning_rate: 5.4188e-04
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8397 - loss: 0.6845 - val_accuracy: 0.8586 - val_loss: 0.6347 - learning_rate: 5.3144e-04
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.8411 - loss: 0.6718 - val_accuracy: 0.8414 - val_loss: 0.6830 - learning_rate: 5.2099e-04
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8418 - loss: 0.6646 - val_accuracy: 0.8520 - val_loss: 0.6523 - learning_rate: 5.1052e-04
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.8397 - loss: 0.6679 - val_accuracy: 0.8547 - val_loss: 0.6356 - learning_rate: 5.0005e-04
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8484 - loss: 0.6470 - val_accuracy: 0.8619 - val_loss: 0.6238 - learning_rate: 4.8958e-04
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8487 - loss: 0.6502 - val_accuracy: 0.8580 - val_loss: 0.6246 - learning_rate: 4.7911e-04
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8477 - loss: 0.6472 - val_accuracy: 0.8412 - val_loss: 0.7006 - learning_rate: 4.6866e-04
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8467 - loss: 0.6455 - val_accuracy: 0.8476 - val_loss: 0.6646 - learning_rate: 4.5822e-04
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8498 - loss: 0.6386 - val_accuracy: 0.8539 - val_loss: 0.6498 - learning_rate: 4.4779e-04
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8438 - loss: 0.6505 - val_accuracy: 0.8609 - val_loss: 0.6145 - learning_rate: 4.3739e-04
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8466 - loss: 0.6384 - val_accuracy: 0.8549 - val_loss: 0.6374 - learning_rate: 4.2702e-04
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8504 - loss: 0.6236 - val_accuracy: 0.8562 - val_loss: 0.6406 - learning_rate: 4.1667e-04
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8507 - loss: 0.6210 - val_accuracy: 0.8609 - val_loss: 0.6111 - learning_rate: 4.0637e-04
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8518 - loss: 0.6237 - val_accuracy: 0.8572 - val_loss: 0.6208 - learning_rate: 3.9610e-04
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8519 - loss: 0.6200 - val_accuracy: 0.8626 - val_loss: 0.5981 - learning_rate: 3.8589e-04
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8522 - loss: 0.6135 - val_accuracy: 0.8580 - val_loss: 0.6222 - learning_rate: 3.7572e-04
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8519 - loss: 0.6112 - val_accuracy: 0.8719 - val_loss: 0.5756 - learning_rate: 3.6560e-04
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8539 - loss: 0.6015 - val_accuracy: 0.8609 - val_loss: 0.5975 - learning_rate: 3.5555e-04
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.8550 - loss: 0.6016 - val_accuracy: 0.8552 - val_loss: 0.6237 - learning_rate: 3.4556e-04
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8578 - loss: 0.5876 - val_accuracy: 0.8555 - val_loss: 0.6138 - learning_rate: 3.3563e-04
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8616 - loss: 0.5796 - val_accuracy: 0.8551 - val_loss: 0.6086 - learning_rate: 3.2578e-04
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8606 - loss: 0.5799 - val_accuracy: 0.8627 - val_loss: 0.5845 - learning_rate: 3.1601e-04
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 40ms/step - accuracy: 0.8608 - loss: 0.5771 - val_accuracy: 0.8712 - val_loss: 0.5640 - learning_rate: 3.0631e-04
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8608 - loss: 0.5734 - val_accuracy: 0.8647 - val_loss: 0.5820 - learning_rate: 2.9670e-04
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8639 - loss: 0.5645 - val_accuracy: 0.8657 - val_loss: 0.5750 - learning_rate: 2.8718e-04
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8622 - loss: 0.5689 - val_accuracy: 0.8663 - val_loss: 0.5769 - learning_rate: 2.7775e-04
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8650 - loss: 0.5608 - val_accuracy: 0.8657 - val_loss: 0.5736 - learning_rate: 2.6843e-04
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8614 - loss: 0.5586 - val_accuracy: 0.8635 - val_loss: 0.5833 - learning_rate: 2.5920e-04
# Restoring model weights from the end of the best epoch: 89.

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
print(f"\n Test Accuracy: {test_acc:.4f}")
# Out:
#  Test Accuracy: 0.8719

# %%
def plot_history(history, title):
    plt.figure(figsize=(14, 5))
    plt.suptitle(title, fontsize=16)

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history["accuracy"], label="Train Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    if 'lr' in history.history:
        ax2 = plt.gca().twinx()
        ax2.plot(history.history['lr'], color='orange', label='Learning Rate', linestyle=':')
        ax2.set_ylabel('Learning Rate', color='orange')
        ax2.tick_params(axis='y', labelcolor='orange')
        lines, labels = plt.gca().get_legend_handles_labels()
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax2.legend(lines + lines2, labels + labels2, loc='lower right')
    else:
        plt.legend()
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.grid(True)

    # Plot Lossx
    plt.subplot(1, 2, 2)
    plt.plot(history.history["loss"], label="Train Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

plot_history(history, "Optimized CNN Training on CIFAR-10 with One-Cycle-like LR")

# %% [markdown]
# Comparison of this model with transfer learning on ResNet model for the same datatset (cifar10) is done in the **"Resnet_cifar10_HW.ipynb"** file
