# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# %%
try:
    with open("short_story.txt", 'r', encoding="utf-8") as f:
        data = f.read()
except FileNotFoundError:
    print("File not found")

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
total = len(tokenizer.word_index) + 1

# %%
input_sequences = []
for line in data.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

# %%
max_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
xs, labels = input_sequences[:, :-1], input_sequences[:, -1]
ys = to_categorical(labels, num_classes=total)

# %%
def RNN_model():
    model = Sequential([
        Embedding(total, 10),
        SimpleRNN(128),
        Dense(total, activation='softmax')
    ])

    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
def LSTM_model():
    model = Sequential([
        Embedding(total, 10),
        LSTM(128),
        Dense(total, activation='softmax')
    ])

    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
def GRU_model():
    model = Sequential([
        Embedding(total, 10),
        GRU(128),
        Dense(total, activation='softmax')
    ])

    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
model1 = RNN_model()
es = EarlyStopping(monitor = 'loss', patience = 10, restore_best_weights=True)
history1 = model1.fit(xs, ys, epochs = 100, callbacks = [es], verbose=1)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0158 - loss: 5.6330
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0920 - loss: 5.3001
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0900 - loss: 5.1534
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0755 - loss: 5.1751
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0864 - loss: 5.1430
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0950 - loss: 5.1620
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0893 - loss: 5.1068
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0779 - loss: 5.0859
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0865 - loss: 5.1253
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1159 - loss: 5.0257
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0860 - loss: 5.0598
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0906 - loss: 5.0600
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0932 - loss: 4.9502
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0911 - loss: 4.9750
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0947 - loss: 4.9598
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0948 - loss: 4.7840
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1239 - loss: 4.5762
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1491 - loss: 4.3820
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1502 - loss: 4.2808
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1832 - loss: 3.9977
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1743 - loss: 3.9009
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1873 - loss: 3.7782
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2146 - loss: 3.5710
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2199 - loss: 3.4944
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3119 - loss: 3.3621
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2763 - loss: 3.2659
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3774 - loss: 2.9468
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4350 - loss: 2.8616
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5371 - loss: 2.6141
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5721 - loss: 2.4014
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6188 - loss: 2.3161
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6354 - loss: 2.2578
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6901 - loss: 2.0611
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7361 - loss: 1.9572
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7771 - loss: 1.7419
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8001 - loss: 1.6289
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8225 - loss: 1.4987
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8237 - loss: 1.4317
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8891 - loss: 1.2872
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8793 - loss: 1.2145
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9122 - loss: 1.1030
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9188 - loss: 1.0151
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9168 - loss: 0.9549
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9446 - loss: 0.8922
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9468 - loss: 0.8190
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9608 - loss: 0.7175
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9623 - loss: 0.6581
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9653 - loss: 0.6047
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9741 - loss: 0.5493
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9760 - loss: 0.5089
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9850 - loss: 0.4775
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9808 - loss: 0.4465
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9883 - loss: 0.4266
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9890 - loss: 0.3819
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9870 - loss: 0.3669
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9897 - loss: 0.3478
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9953 - loss: 0.2977
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9908 - loss: 0.3222
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.2745
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9984 - loss: 0.2651
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9929 - loss: 0.2501
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9986 - loss: 0.2377
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7944 - loss: 1.3385
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8444 - loss: 1.2624
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8423 - loss: 1.1796
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8710 - loss: 1.1004
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8999 - loss: 1.0140
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9174 - loss: 0.9653
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9438 - loss: 0.9035
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9289 - loss: 0.8675
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9429 - loss: 0.7656
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9428 - loss: 0.7486
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9472 - loss: 0.7089
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9541 - loss: 0.6505
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9436 - loss: 0.6185
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9754 - loss: 0.5667
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9657 - loss: 0.5392
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9842 - loss: 0.4753
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9917 - loss: 0.4478
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9924 - loss: 0.4341
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9868 - loss: 0.4118
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9907 - loss: 0.3917
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9894 - loss: 0.3650
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9916 - loss: 0.3378
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9964 - loss: 0.3162
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9980 - loss: 0.3112
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9952 - loss: 0.2882
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9977 - loss: 0.2757
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9975 - loss: 0.2538
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9937 - loss: 0.2494
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9915 - loss: 0.2269
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9986 - loss: 0.2138
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9990 - loss: 0.2055
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9961 - loss: 0.1847
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9990 - loss: 0.1887
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9971 - loss: 0.1805
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9945 - loss: 0.1740
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9945 - loss: 0.1617
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9988 - loss: 0.1501
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9993 - loss: 0.1447
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9954 - loss: 0.1397
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9994 - loss: 0.1311
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9936 - loss: 0.1304
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9994 - loss: 0.1174
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9994 - loss: 0.1170
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9976 - loss: 0.1141
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9957 - loss: 0.1086
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9931 - loss: 0.1115
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9957 - loss: 0.1055
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9965 - loss: 0.0975
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9988 - loss: 0.0933
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9938 - loss: 0.0954
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9960 - loss: 0.0867
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9979 - loss: 0.0836
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9957 - loss: 0.0851
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9993 - loss: 0.0814
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9988 - loss: 0.0770
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9932 - loss: 0.0785

# %%
def predict_next_word(model, seed_text, next_words=1):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        next_word = tokenizer.index_word[np.argmax(predicted)]
        seed_text += ' ' + next_word
    return seed_text

# %%
print(predict_next_word(model1, "Word of Lila", next_words=5))
# Out:
# Word of Lila discovery spread beyond elderglow drawing

# %%
test_loss1, test_acc1 = model1.evaluate(xs, ys)
print(f"RNN Test Accuracy: {test_acc1:.4f}")

test_loss2, test_acc2 = model2.evaluate(xs, ys)
print(f"LSTM Test Accuracy: {test_acc2:.4f}")

test_loss3, test_acc3 = model3.evaluate(xs, ys)
print(f"GRU Test Accuracy: {test_acc3:.4f}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9975 - loss: 0.0579
# RNN Test Accuracy: 0.9981
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9936 - loss: 0.2790
# LSTM Test Accuracy: 0.9962
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9975 - loss: 0.0726
# GRU Test Accuracy: 0.9981

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6)) 

plt.plot(history1.history['accuracy'], label = 'RNN (Training Accuracy)')
plt.plot(history2.history['accuracy'], label = 'LSTM (Training Accuracy)')
plt.plot(history3.history['accuracy'], label = 'GRU (Training Accuracy)')

plt.title("Training Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))

plt.plot(history1.history['loss'], label = 'RNN (Training Loss)')
plt.plot(history2.history['loss'], label = 'LSTM (Training Loss)')
plt.plot(history3.history['loss'], label = 'GRU (Training Loss)')

plt.title("Training Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()


if 'val_accuracy' in history1.history and 'val_accuracy' in history2.history and 'val_accuracy' in history3.history:
    plt.figure(figsize=(10, 6))

    plt.plot(history1.history['val_accuracy'], label = 'RNN (Validation Accuracy)')
    plt.plot(history2.history['val_accuracy'], label = 'LSTM (Validation Accuracy)')
    plt.plot(history3.history['val_accuracy'], label = 'GRU (Validation Accuracy)')

    plt.title("Validation Accuracy Comparison")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

if 'val_loss' in history1.history and 'val_loss' in history2.history and 'val_loss' in history3.history:
    plt.figure(figsize=(10, 6))

    plt.plot(history1.history['val_loss'], label = 'RNN (Validation Loss)')
    plt.plot(history2.history['val_loss'], label = 'LSTM (Validation Loss)')
    plt.plot(history3.history['val_loss'], label = 'GRU (Validation Loss)')

    plt.title("Validation Loss Comparison")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# #  RNN vs LSTM vs GRU – Next Word Prediction Task
#
# ##  Dataset Description
# - Source: `short_story.txt` – a narrative text about a magical forest and a character named Lila.
# - Length: A few rich, descriptive paragraphs with moderate vocabulary.
# - Preprocessing:
#   - Tokenized using Keras' `Tokenizer`
#   - Converted to n-gram sequences
#   - Padded sequences for uniform input
#   - One-hot encoded output labels
#
# ---
#
# ##  Model Setup
# - Input: Sequences of word tokens from the story
# - Architecture:
#   - `Embedding` layer (vocab size = top 3000 words)
#   - One recurrent layer: `SimpleRNN`, `LSTM`, or `GRU` (128 units)
#   - `Dense` layer with softmax activation for next-word prediction
# - Loss Function: `categorical_crossentropy`
# - Optimizer: `adam`
# - Epochs: 100 (with early stopping)
#
# ---
#
# ##  Accuracy Comparison
#
# | Model      | Train Accuracy | Test Accuracy | Final Loss |
# |------------|----------------|----------------|------------|
# | SimpleRNN  | 99.75%         | 99.81%         | 0.0091     |
# | LSTM       | 99.52%         | 99.44%         | 0.2483     |
# | GRU        | 99.75%         | 99.81%         | 0.0730     |
#
# ---
#
# ##  Summary & Learnings
#
# - RNN and GRU performed nearly identically in both training and test accuracy.
# - LSTM performed slightly worse, with higher final loss, possibly due to overfitting on this smaller dataset.
# - GRU showed the best balance between learning capacity and efficiency — likely due to its simpler gate structure compared to LSTM.
# - SimpleRNN surprisingly performed well due to the short sequence length and relatively simple language structure.
# - LSTM can be better than RNN in cases where there is more amount of data and solves vanishing gradient problem.
# - Since here the datset is small it has performed just a bit better than LSTM
#
# ---
#
# ##  Key Takeaways
#
# - For small to moderate datasets, GRU is a great choice — fast and accurate.
# - SimpleRNN can be effective when:
#   - The text is short
#   - Long-term dependencies are minimal
# - LSTM shines more when data has complex, long-range context — not fully leveraged in this case.
# - A well-prepared dataset (clean, well-tokenized text) matters more than just the model architecture.
#
# ---
